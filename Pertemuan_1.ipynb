# %% [markdown]
# <a href="https://colab.research.google.com/github/Egi341/datascience/blob/main/Pertemuan_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pertemuan 1

# %% [markdown]
# Egi Gunawan / IF 401 / PJJ Informatika

# %%
print("Hello UNSIA")
print("Selamat datang di mata kuliah Data Science")
# Out:
# Hello UNSIA
# Selamat datang di mata kuliah Data Science

# %% [markdown]
# Variabel dan type data

# %%
nama = "Egi Gunawan"
kelas = "IF 401"
jurusan = "PJJ Informatika"

print(f"Nama : {nama}")
print(f"Kelas : {kelas}")
print(f"Jurusan : {jurusan}")
# Out:
# Nama : Egi Gunawan
# Kelas : IF 401
# Jurusan : PJJ Informatika

# %% [markdown]
# List dan Pengulangan

# %%
tools = ["phyton", "Google Colab", "Github"]

print("\nTools Data Science:")
for i, tool in enumerate(tools,1):
  print(f"{i}.{tools}")
# Out:
# Tools Data Science:
# 1.['phyton', 'Google Colab', 'Github']
# 2.['phyton', 'Google Colab', 'Github']
# 3.['phyton', 'Google Colab', 'Github']
